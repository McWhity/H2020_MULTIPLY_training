# %% [markdown]
# # Welcome to the Smart Farming Practical Lab! 🌾🚀
#
# Before we dive deeper into smart farming applications, let's take **5 minutes** to benchmark where everyone is starting from. This will help tailor the pacing of the coding blocks.
#
# ---
#
# ## 📊 Quick Self-Assessment
#
# Please fill out the tables below by placing an **`X`** in the column that best matches your experience level.
# *(To edit, double-click this cell, type your response, and press `Shift + Enter` to re-render).*
#
# ### 1. Programming & Data Science Background
# | Skill | Never heard of it | Know the theory | Written some code | Comfortable/Expert |
# | :--- | :---: | :---: | :---: | :---: |
# | **Python** | [ ] | [ ] | [ ] | [ ] |
# | **Pandas / Xarray / Numpy** | [ ] | [ ] | [ ] | [ ] |
# | **Jupyter Notebooks** | [ ] | [ ] | [ ] | [ ] |
# | **Working with Geospatial Data (GIS)** | [ ] | [ ] | [ ] | [ ] |
# | **QGIS (Desktop GIS)** | [ ] | [ ] | [ ] | [ ] | [ ] |
#
# ### 2. Smart Farming & Remote Sensing Background
# | Concept | No Clue | Basic Concept | Used Web Tools | Programmed with it |
# | :--- | :---: | :---: | :---: | :---: |
# | **Satellite Imagery (Optical/Radar)** | [ ] | [ ] | [ ] | [ ] |
# | **Agricultural Indices (NDVI, NDRE)** | [ ] | [ ] | [ ] | [ ] |
# | **API Portals (Copernicus, GEE, ASF)** | [ ] | [ ] | [ ] | [ ] |
# | **Precision Agronomy / Variable Rate**| [ ] | [ ] | [ ] | [ ] |
#
# ---
#
# ## 📝 Short Answer Expectations
#
# Type your brief answers directly below each question:
#
# ### Q1: What is your main study background? (e.g., Agronomy, Computer Science, Environmental Studies, etc.)
# > *Your answer here*
#
# ### Q2: What is your primary expectation or goal for this course?
# > *Your answer here*
#
# ### Q3: Job Readiness: What field or industry do you see yourself working in after graduation, and how do you hope building automated smart farming pipelines will give you a competitive edge there?
# > *Your answer here*
#
# ---

# %% [markdown]
# ## ↩️ Previous Session Synchronization
#
# Since I am stepping in to lead this session, let's make sure we seamlessly connect today's lab with what you have already built, analyzed, or discussed in your previous classes.
#
# Please take **2 minutes** to check the boxes and briefly summarize your baseline.
#
# ### 1. What have you already covered?
# *Check all that apply by replacing `[ ]` with `[X]`:*
#
# - [ ] Basic principles of remote sensing (orbits, wavelengths, resolution)
# - [ ] Manual file downloads (e.g., downloading `.zip` or `.tar.gz` files from USGS or ESA Copernicus)
# - [ ] Working with GIS layers (vector shapefiles, field boundaries, raster layers)
# - [ ] Basic Python programming basics (for loops, functions, lists)
# - [ ] Data science basics (importing `pandas`, `numpy`, or plotting with `matplotlib`)
# - [ ] Agronomic theory (crop growth stages, nitrogen cycles, soil moisture basics)
#
# ### 2. Open-Ended Sync Questions
#
# ### Q1: What was the exact focus or final exercise of your very last session?
# > *Your answer here*
#
# ### Q2: Do you have any any specific scripts, tools, or concepts from the previous sessions?
# > *Your answer here*
#
# ---

# %% [markdown]
# ### 🛠️ Next Up:

# %% [markdown]
# # 📝 Homework Assignment: Cross-Platform Earth Observation & Index Discovery
# **Due Date:** Before the start of next class
# **Estimated Time:** ??? hours
#
# ---
#
# ### 🎯 Assignment Objectives
# 1. Bridge the gap between **cloud-programmatic pipelines** (Jupyter), **traditional desktop GIS software** (QGIS/ArcGIS), and **web-based visual explorers** (Copernicus Browser).
# 2. Discover how different platforms handle and process the exact same raw satellite data structures.
# 3. Test your pipeline code against new global landscapes to identify real-world data constraints and edge cases.
#
# ---
#
# ## 🛰️ Part 1: Hands-on Desktop GIS (ArcGIS Pro or QGIS)
#
# 1. **Download a Dataset:** Go to the Copernicus Data Space Ecosystem (or your assigned regional data hub) and search for a cloud-free **Sentinel-2 (Level-2A)** scene. Download the zipped product folder to your local machine.
# 2. **Examine the File Tree:** Extract the folder. Notice that it isn't a simple, flat image file, but a complex nested directory structure. Explore and get a feeling for the data.
# 3. **Load into Desktop GIS:** Open your GIS software (ArcGIS Pro or QGIS). Drag and drop **Band 4 (Red)** and **Band 8 (Near-Infrared)** into your active map workspace layout.
#
# ---
#
# ## 🌐 Part 2: Quick Exploration via Copernicus Browser
#
# 1. **Navigate & Locate:** Open the [Copernicus Browser Workspace](https://browser.dataspace.copernicus.eu/). Zoom into the exact same agricultural zone or city grid you chose for Part 1.
# 2. **Discover Available Data:** Use the search filters on the left panel to explore data outside of Sentinel-2.
# 3. List at least **two other satellite constellations** (e.g., Sentinel-1, Sentinel-3, Landsat, or Envisat) available in this browser configuration for your region. In your own words, briefly state what physical characteristics one of those alternative sensors captures (e.g., microwave radar backscatter, thermal signatures, ocean color).
#
# ---
#
# ## 💻 Part 3: Python Pipeline Stress-Test (Jupyter Notebook)
#
# 1. **Modify Your Sandbox:** Open the Jupyter Notebook we built together during today's lab session.
# 2. **Shift Geography & Timeline:** Change your `aoi_geometry` coordinates to a completely different agricultural region of the world and adjust

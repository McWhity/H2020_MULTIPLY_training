# %% [markdown]
# Excerxise
# download dataset from copernicus data hub
# try using the copernicus playground (what data do you find)
# try to use the jupyter notebooks to calculate another indices for other fields, regions
#
# Next time give me feedback, ask questions, what problems did occur, ...
